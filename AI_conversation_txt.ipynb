# %% [markdown]
# Problem 1: Tip Calculator

# %% [markdown]
# ### Tip Calculator
#
# This program calculates the tip amount and the total bill based on the bill amount and tip percentage. The results are formatted as currency with two decimal places.

# %% [markdown]
# This program lets restaurant staff quickly calculate a tip and the final total for a customer’s bill. Staff enter the bill amount and a tip percentage, and the tool returns the tip amount and the total charge to process. Inputs and outputs Inputs: Bill amount Tip percentage Input data types: Bill amount: Number (currency, e.g., 45.80) Tip percentage: Number (percentage, e.g., 15) Outputs: Tip amount Total amount to charge (bill + tip) Output format: Currency values shown to two decimal places (e.g., $6.87, $52.67) Hand calculation example (bill $45.80, tip 15%) First calculation I would do: Compute the tip amount using Tip = Bill × ( Tip % 100 ) = 45.80 × ( 15 100 ) = 45.80 × 0.15 = 6.87 Second calculation: Compute the total amount to charge Total = Bill + Tip = 45.80 + 6.87 = 52.67 Final step: Round to two decimal places (already exact here) and format as currency. What I would tell the staff member: Tip amount: $6.87 Total to charge: $52.67
# Here's a program that calculates the tip amount and the total bill based on the bill amount and tip percentage you enter. The results will be formatted as currency with two decimal places.
#
#
# The bill amount is 45.80
#
#
# Okay, the bill amount is $45.80. What is the tip percentage you would like to apply?
#
#
# The tip percentage is 15
#
#
# Thank you! I have both the bill amount ($45.80) and the tip percentage (15%). Would you like me to run the calculation?
#
#
# Yes calculate the total and give me the results
#
#
# Great! I've updated the code to use a bill amount of $45.80 and a 15% tip. Please run the code cell below to see the calculated tip amount and total charge.
#
# The calculations are complete! Here are the results:
#
# Tip amount: $6.87 * **Total to charge:** $$6.87 * **Total to charge:** $52.67

# %% [markdown]
# Problem 2: Late Fee Calculator

# %% [markdown]
# ### Perth Library Overdue Book Fine Calculator
#
# This program calculates overdue book fines for the Perth library. It takes the number of days a book is late, applies a fine of $0.50 per day, with a maximum cap of $10.00. It also provides a clear message if the maximum fine is reached.

# %% [markdown]
# This program helps Perth library staff calculate overdue book fines based on how many days late a book is. The fine is $0.50 per day, with a maximum of $10.00, and the program should also handle the case where the fine reaches the maximum by showing a clear message. Inputs and outputs Inputs: Days overdue: Number of days the book is returned late (non-negative integer). Outputs: Fine amount: Currency value to two decimal places, capped at $10.00. Special case: If the calculated fine exceeds $10.00, show “Maximum fine reached” and $10.00. Work the problem by hand Case A: Book is 5 days late My calculation: Base fine: 5 days × $0.50/day = $2.50 Cap check: $2.50 ≤ $10.00 → no cap applied Fine: $2.50 Case B: Book is 25 days late My calculation: Base fine: 25 days × $0.50/day = $12.50 Cap check: $12.50 > $10.00 → apply cap Fine: $10.00 Special note: The fine would have been $12.50, but the library’s policy caps fines at $10.00, so we show “Maximum fine reached.” Case C: Book is 0 days late Fine: $0.00
# Okay, I've got the details for the Perth library overdue book fine calculator. Here's a program that takes the days a book is late, calculates the fine, applies the $10.00 cap, and displays the appropriate message. Please run the code cell below to use it.
#
#
# The number of days the book is overdue is 5,calculate the fine
#
#
# Okay, I've updated the code with the book being 5 days overdue. Please run the code cell below to calculate the fine.
#
#
# The number of days the book is overdue is 25,calculate the fine
#
#
# The code is set up to calculate the fine for 25 days overdue. Please run the code cell containing the 'Perth Library Overdue Book Fine Calculator' to see the fine amount.
#
#
# The book is 0 days late,calculate the fine amount
#
#
# Okay, I've updated the code to calculate the fine for a book that is 0 days late. Please run the code cell to see the fine amount.
