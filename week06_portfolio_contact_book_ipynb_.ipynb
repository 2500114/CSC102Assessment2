# %%
# TODO: Create a dictionary called `contacts` with 3 entries
# Each key should be a person's name, each value their phone number (string)

contacts = {
    "Alice": "0400 123 456",
    "Bob": "0411 000 999",
    "Charlie": "0422 333 777",
}
contacts

# TODO: Add yourself (or another name) to the contacts dictionary

contacts["Mercy"] = "0499 888 222"
contacts

# TODO: Change Bob's number

contacts["Bob"] = "0401 555 000"
contacts

# TODO: Loop  and print each contact


for name, phone in contacts.items():
    print(f"{name}: {phone}")

    # TODO: Redesign `contacts` so each entry stores both a phone and an email

contacts = {
    "Alice": {
        "phone": "0400 123 456",
        "email": "alice@example.com"
    },
    "Bob": {
        "phone": "0401 555 000",
        "email": "bob@example.com"
    },
    "Charlie": {
        "phone": "0422 333 777",
        "email": "charlie@example.com"
    },
    "YourName": {
        "phone": "0499 888 222",
        "email": "Mercy@example.com"
    }
}

contacts

# TODO: Loop  and print both phone and email

for name, info in contacts.items():
    print(f"{name}")
    print(f"  Phone: {contacts[name]['phone']}")
    print(f"  Email: {contacts[name]['email']}")


critique_notes = """
1) The structure uses lists for values, so you must remember positions like v[1] or v[3],
   which makes the data hard to understand and error-prone.

2) Names and attributes are hidden behind short keys ("n", "v"), reducing readability.
   Lookups are difficult because people are stored in a list instead of a dictionary.

Redesign idea:
Use a simple dictionary-of-dictionaries:
{
  "Alice": {"phone": "...", "email": "..."},
  "Bob": {"phone": "...", "email": "..."}
}
This allows fast lookups by name and readable attribute access.
"""
# Out:
# Alice: 0400 123 456
# Bob: 0401 555 000
# Charlie: 0422 333 777
# Mercy: 0499 888 222
# Alice
#   Phone: 0400 123 456
#   Email: alice@example.com
# Bob
#   Phone: 0401 555 000
#   Email: bob@example.com
# Charlie
#   Phone: 0422 333 777
#   Email: charlie@example.com
# YourName
#   Phone: 0499 888 222
#   Email: Mercy@example.com
